# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import geopandas
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
base = world.plot(color='white', edgecolor='black')
base
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(18,14))

ax = base

world[world.name == 'South Korea'].plot()
world[world.name == 'China'].plot()
world[world.name == 'United States of America'].plot()
world[world.name == 'Sweden'].plot()
world[world.name == 'Russia'].plot()
world[world.name == 'France'].plot()
world[world.name == 'Canada'].plot()
world[world.name == 'Denmark'].plot()
world[world.name == 'Taiwan'].plot()
world[world.name == 'Germany'].plot()
# Out:
# <AxesSubplot:>
